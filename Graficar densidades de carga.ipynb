# %%
import scipy as scp
import numpy as np
import sympy as sp
from scipy.special import jn, yn, jn_zeros, yn_zeros

# %%
#-------------VERSIÓN MÁS "LIMPIA"--------------------
import sympy as sp
import scipy as scp
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jn, yn, jn_zeros, yn_zeros

# Definir las variables y los parámetros

v_max = 17  # límite superior para el índice v
r = sp.Symbol('r', real=True, positive=True)
R = sp.Symbol('R', real=True, positive=True)
a = sp.symbols('a1:%d' % (v_max+1))  # coeficientes a1, a2, ..., a17

# Expresión de la densidad de carga usando una serie de funciones de Bessel
rho_expr = sum(a[v-1] * sp.besselj(0, v * sp.pi * r / R) for v in range(1, v_max+1))

def densidad(r_val,a_values):
    R_val=8.0
    for i in r_val:
        if i > R_val:
            return 0
    
        else:
            # Sustituir los valores de r, R y los coeficientes en la expresión
            rho=sp.lambdify(r,rho_expr.subs(R,R_val).subs(dict(zip(a,a_values))), modules=[{'besselj':jn},'numpy'])
            return rho(r_val)

#VALOR DE PARÁMETROS-------------------------------------
R_val= 8.0
a_values_12C=[0.15721e-1,0.38732e-1,0.36808e-1,0.14671e-1,-0.43277e-2,-0.97752e-2,-0.68908e-2,
              -0.27631e-2,-0.63568e-3,0.71809e-4,0.18441e-3,0.75066e-4,0.51069e-4,0.14308e-4,0.23170e-5,0.68465e-6,0]

a_values_16O=[0.20238e-1,0.44793e-1,0.33533e-1,0.35030e-2,-0.12293e-1,-0.10329e-1,-0.34036e-2,
              -0.41627e-3,-0.94435e-3,-0.25771e-3,0.23759e-3,-0.10603e-3,0.41480e-4,0,0,0,0]
a_values_40Ca=[0.44846e-1,0.61326e-1,-0.16818e-2,-0.26217e-1,-0.29725e-2,0.85534e-2,0.35322e-2,
               -0.48258e-3,-0.39346e-3,0.20338e-3,0.25461e-4,-0.17794e-4,0.67394e-5,-0.21033e-5,0,0,0]
a_values_48Ca=[0.44782e-1,0.59523e-1,-0.74148e-2,-0.29466e-1,-0.28350e-3,0.10829e-1,0.30465e-2,
               -0.10237e-2,-0.17830e-3,0.55391e-4,-0.22644e-4,0.82671e-5,-0.27343e-5,0.82461e-6,-0.22780e-6,0,0]





density12C3=[0.84106e-01,0.83861e-01,0.82808e-01,0.80314e-01,0.75862e-01,0.69122e-01,0.59999e-01,0.48915e-01,0.36947e-01,0.25577e-01,0.16180e-01,0.94436e-02,0.51856e-02,0.27275e-02,0.13954e-02,0.70678e-03,0.35560e-03,0.17760e-03,0.90856e-04,0.46468e-04,0.22733e-04,0.12453e-04,0.67553e-05,0.26344e-05,0.18777e-05,0.13133e-05,0.71069e-07,0.29671e-06,0.51576e-06,0.39288e-06
, 0.71045e-11]
density12CZ=[0.74402e-01,0.74239e-01,0.73719e-01,0.72762e-01,0.71264e-01,0.69121e-01,0.66248e-01,0.62593e-01,0.58147e-01,0.52966e-01
, 0.47173e-01,0.40961e-01,0.34579e-01,0.28311e-01,0.22446e-01,0.17233e-01,0.12836e-01,0.93077e-02,0.66007e-02,0.45988e-02
, 0.31610e-02,0.21518e-02,0.14559e-02,0.98171e-03,0.66085e-03,0.44466e-03,0.29965e-03,0.20261e-03,0.13738e-03,0.93211e-04
, 0.63328e-04,0.43292e-04,0.29797e-04,0.20442e-04,0.13870e-04,0.94270e-05,0.65440e-05,0.45499e-05,0.30027e-05,0.18716e-05
, 0.77058e-03,0.36489e-03,0.16950e-03,0.76978e-04,0.34450e-04,0.15599e-04,0.67799e-05,0.25891e-05,0.11648e-05,0.63609e-06
, 0.33244e-07,0.12701e-06,0.13274e-06,0.51114e-07,0.18237e-06,0.36205e-11]
density48CaZ=[0.80564e-01,0.80291e-01,0.79503e-01,0.78287e-01,0.76781e-01,0.75151e-01,0.73557e-01,0.72115e-01,0.70861e-01,0.69740e-01
, 0.68619e-01,0.67314e-01,0.65631e-01,0.63398e-01,0.60494e-01,0.56862e-01,0.52513e-01,0.47529e-01,0.42054e-01,0.36286e-01
, 0.30459e-01,0.24821e-01,0.19604e-01,0.14994e-01,0.11107e-01,0.79790e-02,0.55705e-02,0.37905e-02,0.25220e-02,0.16458e-02
, 0.10565e-02,0.66914e-03,0.41925e-03,0.26031e-03,0.16024e-03,0.97823e-04,0.59330e-04,0.35874e-04,0.21628e-04,0.12884e-04
, 0.74802e-05,0.42413e-05,0.24314e-05,0.14471e-05,0.82559e-06,0.35386e-06,0.48761e-07,0.40563e-07,0.12437e-07,0.49332e-07
, 0.11667e-07,0.10156e-06,0.10248e-06,0.37905e-11]


r_vals= np.linspace(0, R_val+1, 500)
r_density12C3=np.linspace(0,R_val+1,len(density12C3))
r_density12CZ=np.linspace(0,R_val+1,len(density12CZ))

r_density16O3=np.linspace(0,R_val+1,len(density16O3))
r_density16OZ=np.linspace(0,R_val+1,len(density16OZ))

r_density40Ca3=np.linspace(0,R_val+1,len(density40Ca3))
r_density40CaZ=np.linspace(0,R_val+1,len(density40CaZ))

r_density48Ca3=np.linspace(0,R_val+1,len(density48Ca3))
r_density48CaZ=np.linspace(0,R_val+1,len(density48CaZ))

# %%
#12C
plt.plot(r_vals,densidad(r_vals,a_values_12C),label=r'$\rho(r)$',linestyle="--")
plt.plot(r_density12C3,density12C3,label=r'$\rho_{Skyrme-3}(r)$',marker="o",ms=3,linestyle="",color="r")
plt.plot(r_density12CZ,density12CZ,label=r'$\rho_{Skp}(r)$',marker="o",ms=3,linestyle="",color="g")

plt.xlabel(r'$r$')
plt.ylabel(r'$\rho(r)$')
#plt.title(r'Densidad de carga para el $^{12}$C')
plt.legend()
plt.grid(True)
plt.show()

# %%
#16O
plt.plot(r_vals,densidad(r_vals,a_values_16O),label=r'$\rho(r)$',linestyle="--")
plt.plot(r_density16O3,density16O3,label=r'$\rho_{Skyrme-3}(r)$',marker="o",ms=3,linestyle="",color="r")
plt.plot(r_density16OZ,density16OZ,label=r'$\rho_{Skp}(r)$',marker="o",ms=3,linestyle="",color="g")

plt.xlabel(r'$r$')
plt.ylabel(r'$\rho(r)$')
#plt.title(r'Densidad de carga para el $^{16}$O')
plt.legend()
plt.grid(True)
plt.show()

# %%
#40Ca
plt.plot(r_vals, densidad(r_vals,a_values_40Ca), label=r'$\rho(r)$',linestyle="--")
plt.plot(r_density40Ca3,density40Ca3,label=r'$\rho_{Skyrme-3}(r)$',marker="o",ms=3,linestyle="",color="r")
plt.plot(r_density40CaZ,density40CaZ,label=r'$\rho_{Skp}(r)$',marker="o",ms=3,linestyle="",color="g")

plt.xlabel(r'$r$')
plt.ylabel(r'$\rho(r)$')
#plt.title(r'Densidad de carga para el $^{40}$Ca')
plt.legend()
plt.grid(True)
plt.show()

# %%
#48Ca
plt.plot(r_vals, densidad(r_vals,a_values_48Ca), label=r'$\rho(r)$',linestyle="--")
plt.plot(r_density48Ca3,density48Ca3,label=r'$\rho_{Skyrme-3}(r)$',marker="o",ms=3,linestyle="",color="r")
plt.plot(r_density48CaZ,density48CaZ,label=r'$\rho_{Skp}(r)$',marker="o",ms=3,linestyle="",color="g")

plt.xlabel(r'$r$')
plt.ylabel(r'$\rho(r)$')
#plt.title(r'Densidad de carga para el $^{48}$Ca')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import scipy as scp
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jn, yn, jn_zeros, yn_zeros

# Definir las variables y los parámetros

v_max = 17  # límite superior para el índice v
r = sp.Symbol('r', real=True, positive=True)
R = sp.Symbol('R', real=True, positive=True)
a = sp.symbols('a1:%d' % (v_max+1))  # coeficientes a1, a2, ..., a17

# Expresión de la densidad de carga usando una serie de funciones de Bessel
rho_expr = sum(a[v-1] * sp.besselj(0, v * sp.pi * r / R) for v in range(1, v_max+1))

def densidad(r_val,R_val,a_values):
    if r_val > R_val:
        return 0
    else:
        # Sustituir los valores de r, R y los coeficientes en la expresión
        
        return rho_expr.subs({r: r_val, R: R_val, **dict(zip(a, a_values))})

#VALOR DE PARÁMETROS-------------------------------------
R_val= 8.0
a_values_12C=[0.15721e-1,0.38732e-1,0.36808e-1,0.14671e-1,-0.43277e-2,-0.97752e-2,-0.68908e-2,
              -0.27631e-2,-0.63568e-3,0.71809e-4,0,18441e-3,0.75066e-4,0.51069e-4,0.14308e-4,0.23170e-5,0.68465e-6,0]
a_values_16O=[0.20238e-1,0.44793e-1,0.33533e-1,0.35030e-2,-0.12293e-1,-0.10329e-1,-0.34036e-2,
              -0.41627e-3,-0.94435e-3,-0.25771e-3,0.23759e-3,-0.10603e-3,0.41480e-4,0,0,0,0]
a_values_40Ca=[0.44846e-1,0.61326e-1,-0.16818e-2,-0.26217e-1,-0.29725e-2,0.85534e-2,0.35322e-2,
               -0.48258e-3,-0.39346e-3,0.20338e-3,0.25461e-4,-0.17794e-4,0.67394e-5,-0.21033e-5,0,0,0]
a_values_48Ca=[0.44782e-1,0.59523e-1,-0.74148e-2,-0.29466e-1,-0.28350e-3,0.10829e-1,0.30465e-2,
               -0.10237e-2,-0.17830e-3,0.55391e-4,-0.22644e-4,0.82671e-5,-0.27343e-5,0.82461e-6,-0.22780e-6,0,0]

#GRAFICAR-----------------------------
rho_12C = sp.lambdify(r,rho_expr.subs(R,R_val).subs(dict(zip(a,a_values_12C))), modules=[{'besselj':jn},'numpy'])
rho_16O = sp.lambdify(r,rho_expr.subs(R,R_val).subs(dict(zip(a,a_values_16O))), modules=[{'besselj':jn},'numpy'])
rho_40Ca = sp.lambdify(r,rho_expr.subs(R,R_val).subs(dict(zip(a,a_values_40Ca))), modules=[{'besselj':jn},'numpy'])
rho_48Ca = sp.lambdify(r,rho_expr.subs(R,R_val).subs(dict(zip(a,a_values_48Ca))), modules=[{'besselj':jn},'numpy'])

r_vals= np.linspace(0, R_val+1, 500)

rho_12C_eval = rho_12C(r_vals)
rho_16O_eval = rho_16O(r_vals)
rho_40Ca_eval = rho_40Ca(r_vals)
rho_48Ca_eval = rho_48Ca(r_vals)

plt.plot(r_vals, rho_48Ca_eval, label=r'$\rho(r)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$\rho(r)$')
plt.title(r'Densidad de carga $\rho(r)$ en función de $r$')
plt.legend()
plt.grid(True)
plt.show()
